# %% [markdown]
# ## 1. Extracting Data from a Data Source.

# %%
! rm -rf LoanStats_web.csv

# %%
! wget https://storage.googleapis.com/aekanunlab/LoanStats_web.csv
# Out:
# --2020-08-23 02:35:55--  https://storage.googleapis.com/aekanunlab/LoanStats_web.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 172.217.214.128, 108.177.111.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1160157683 (1.1G) [text/csv]
# Saving to: ‘LoanStats_web.csv’
#
# LoanStats_web.csv   100%[===================>]   1.08G   124MB/s    in 8.2s
#
# 2020-08-23 02:36:03 (134 MB/s) - ‘LoanStats_web.csv’ saved [1160157683/1160157683]

# %%
! wc -l LoanStats_web.csv
# Out:
# 1432493 LoanStats_web.csv

# %%
! head -2 LoanStats_web.csv
# Out:
# "id","member_id","loan_amnt","funded_amnt","funded_amnt_inv","term","int_rate","installment","grade","sub_grade","emp_title","emp_length","home_ownership","annual_inc","verification_status","issue_d","loan_status","pymnt_plan","url","desc","purpose","title","zip_code","addr_state","dti","delinq_2yrs","earliest_cr_line","inq_last_6mths","mths_since_last_delinq","mths_since_last_record","open_acc","pub_rec","revol_bal","revol_util","total_acc","initial_list_status","out_prncp","out_prncp_inv","total_pymnt","total_pymnt_inv","total_rec_prncp","total_rec_int","total_rec_late_fee","recoveries","collection_recovery_fee","last_pymnt_d","last_pymnt_amnt","next_pymnt_d","last_credit_pull_d","collections_12_mths_ex_med","mths_since_last_major_derog","policy_code","application_type","annual_inc_joint","dti_joint","verification_status_joint","acc_now_delinq","tot_coll_amt","tot_cur_bal","open_acc_6m","open_act_il","open_il_12m","open_il_24m","mths_since_rcnt_il","total_bal_il","il_util","open_rv_12m","open_rv_24m","max_bal_bc","all_util","total_rev_hi_lim","inq_fi","total_cu_tl","inq_last_12m","acc_open_past_24mths","avg_cur_bal","bc_open_to_buy","bc_util","chargeoff_within_12_mths","delinq_amnt","mo_sin_old_il_acct","mo_sin_old_rev_tl_op","mo_sin_rcnt_rev_tl_op","mo_sin_rcnt_tl","mort_acc","mths_since_recent_bc","mths_since_recent_bc_dlq","mths_since_recent_inq","mths_since_recent_revol_delinq","num_accts_ever_120_pd","num_actv_bc_tl","num_actv_rev_tl","num_bc_sats","num_bc_tl","num_il_tl","num_op_rev_tl","num_rev_accts","num_rev_tl_bal_gt_0","num_sats","num_tl_120dpd_2m","num_tl_30dpd","num_tl_90g_dpd_24m","num_tl_op_past_12m","pct_tl_nvr_dlq","percent_bc_gt_75","pub_rec_bankruptcies","tax_liens","tot_hi_cred_lim","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit","revol_bal_joint","sec_app_earliest_cr_line","sec_app_inq_last_6mths","sec_app_mort_acc","sec_app_open_acc","sec_app_revol_util","sec_app_open_act_il","sec_app_num_rev_accts","sec_app_chargeoff_within_12_mths","sec_app_collections_12_mths_ex_med","sec_app_mths_since_last_major_derog","hardship_flag","hardship_type","hardship_reason","hardship_status","deferral_term","hardship_amount","hardship_start_date","hardship_end_date","payment_plan_start_date","hardship_length","hardship_dpd","hardship_loan_status","orig_projected_additional_accrued_interest","hardship_payoff_balance_amount","hardship_last_payment_amount","debt_settlement_flag","debt_settlement_flag_date","settlement_status","settlement_date","settlement_amount","settlement_percentage","settlement_term"
# "","","12800","12800","12800"," 36 months"," 11.99%","425.09","C","C1","LOGISTICS COORDINATOR","6 years","MORTGAGE","53000","Verified","Mar-2016","Fully Paid","n","","","credit_card","Credit card refinancing","330xx","FL","20.99","0","Mar-2002","0","","59","7","1","8777","79.1%","16","w","0.00","0.00","15289.8112319621","15289.81","12800.00","2489.81","0.0","0.0","0.0","Apr-2019","424.75","","Mar-2019","0","","1","Individual","","","","0","0","221036","2","2","1","1","9","23227","68","1","1","3381","71","11100","1","0","2","3","31577","962","87.8","0","0","124","168","4","4","1","43","","7","","0","3","4","3","4","7","4","8","4","7","0","0","0","3","100","100","1","0","235600","32004","7900","34024","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""

# %% [markdown]
# ## 2. Loading the data into the HDFS (Raw Zone).

# %%
! hdfs dfs -rm /user/root/LoanStats_web.csv
# Out:
# Deleted /user/root/LoanStats_web.csv

# %%
! hdfs dfs -put LoanStats_web.csv /user/root/

# %%
! hdfs dfs -ls /user/root/
# Out:
# Found 3 items
# drwxr-xr-x   - root hadoop          0 2020-08-23 02:35 /user/root/.sparkStaging
# -rw-r--r--   2 root hadoop 1160157683 2020-08-23 02:36 /user/root/LoanStats_web.csv
# drwxr-xr-x   - root hadoop          0 2020-08-23 02:12 /user/root/crunched_data

# %% [markdown]
# ## 3. Transformation the data using Apache Spark and Save them back to HDFS (Trusted Zone).

# %%
sc
# Out:
# <SparkContext master=yarn appName=pyspark-shell>

# %%
raw_df = spark.read.format('csv').option('header','true').option('mode','DROPMALFORMED')\
.load('/user/root/LoanStats_web.csv')

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /opt/conda/lib/python3.7/site-packages (from pandas) (1.19.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)

# %%
raw_pandas = raw_df.limit(10).toPandas()

# %%
import pandas as pd

# %%
raw_pandas.shape[1]+1
# Out:
# 145

# %%
pd.set_option('display.max_rows', raw_pandas.shape[1]+1)

# %%
raw_pandas.transpose()
# Out:
#                                                                   0  \
# id                                                             None
# member_id                                                      None
# loan_amnt                                                     12800
# funded_amnt                                                   12800
# funded_amnt_inv                                               12800
# term                                                      36 months
# int_rate                                                     11.99%
# installment                                                  425.09
# grade                                                             C
# sub_grade                                                        C1
# emp_title                                     LOGISTICS COORDINATOR
# emp_length                                                  6 years
# home_ownership                                             MORTGAGE
# annual_inc                                                    53000
# verification_status                                        Verified
# issue_d                                                    Mar-2016
# loan_status                                              Fully Paid
# pymnt_plan                                                        n
# url                                                            None
# desc                                                           None
# purpose                                                 credit_card
# title                                       Credit card refinancing
# zip_code                                                      330xx
# addr_state                                                       FL
# dti                                                           20.99
# delinq_2yrs                                                       0
# earliest_cr_line                                           Mar-2002
# inq_last_6mths                                                    0
# mths_since_last_delinq                                         None
# mths_since_last_record                                           59
# open_acc                                                          7
# pub_rec                                                           1
# revol_bal                                                      8777
# revol_util                                                    79.1%
# total_acc                                                        16
# initial_list_status                                               w
# out_prncp                                                      0.00
# out_prncp_inv                                                  0.00
# total_pymnt                                        15289.8112319621
# total_pymnt_inv                                            15289.81
# total_rec_prncp                                            12800.00
# total_rec_int                                               2489.81
# total_rec_late_fee                                              0.0
# recoveries                                                      0.0
# collection_recovery_fee                                         0.0
# last_pymnt_d                                               Apr-2019
# last_pymnt_amnt                                              424.75
# next_pymnt_d                                                   None
# last_credit_pull_d                                         Mar-2019
# collections_12_mths_ex_med                                        0
# mths_since_last_major_derog                                    None
# policy_code                                                       1
# application_type                                         Individual
# annual_inc_joint                                               None
# dti_joint                                                      None
# verification_status_joint                                      None
# acc_now_delinq                                                    0
# tot_coll_amt                                                      0
# tot_cur_bal                                                  221036
# open_acc_6m                                                       2
# open_act_il                                                       2
# open_il_12m                                                       1
# open_il_24m                                                       1
# mths_since_rcnt_il                                                9
# total_bal_il                                                  23227
# il_util                                                          68
# open_rv_12m                                                       1
# open_rv_24m                                                       1
# max_bal_bc                                                     3381
# all_util                                                         71
# total_rev_hi_lim                                              11100
# inq_fi                                                            1
# total_cu_tl                                                       0
# inq_last_12m                                                      2
# acc_open_past_24mths                                              3
# avg_cur_bal                                                   31577
# bc_open_to_buy                                                  962
# bc_util                                                        87.8
# chargeoff_within_12_mths                                          0
# delinq_amnt                                                       0
# mo_sin_old_il_acct                                              124
# mo_sin_old_rev_tl_op                                            168
# mo_sin_rcnt_rev_tl_op                                             4
# mo_sin_rcnt_tl                                                    4
# mort_acc                                                          1
# mths_since_recent_bc                                             43
# mths_since_recent_bc_dlq                                       None
# mths_since_recent_inq                                             7
# mths_since_recent_revol_delinq                                 None
# num_accts_ever_120_pd                                             0
# num_actv_bc_tl                                                    3
# num_actv_rev_tl                                                   4
# num_bc_sats                                                       3
# num_bc_tl                                                         4
# num_il_tl                                                         7
# num_op_rev_tl                                                     4
# num_rev_accts                                                     8
# num_rev_tl_bal_gt_0                                               4
# num_sats                                                          7
# num_tl_120dpd_2m                                                  0
# num_tl_30dpd                                                      0
# num_tl_90g_dpd_24m                                                0
# num_tl_op_past_12m                                                3
# pct_tl_nvr_dlq                                                  100
# percent_bc_gt_75                                                100
# pub_rec_bankruptcies                                              1
# tax_liens                                                         0
# tot_hi_cred_lim                                              235600
# total_bal_ex_mort                                             32004
# total_bc_limit                                                 7900
# total_il_high_credit_limit                                    34024
# revol_bal_joint                                                None
# sec_app_earliest_cr_line                                       None
# sec_app_inq_last_6mths                                         None
# sec_app_mort_acc                                               None
# sec_app_open_acc                                               None
# sec_app_revol_util                                             None
# sec_app_open_act_il                                            None
# sec_app_num_rev_accts                                          None
# sec_app_chargeoff_within_12_mths                               None
# sec_app_collections_12_mths_ex_med                             None
# sec_app_mths_since_last_major_derog                            None
# hardship_flag                                                     N
# hardship_type                                                  None
# hardship_reason                                                None
# hardship_status                                                None
# deferral_term                                                  None
# hardship_amount                                                None
# hardship_start_date                                            None
# hardship_end_date                                              None
# payment_plan_start_date                                        None
# hardship_length                                                None
# hardship_dpd                                                   None
# hardship_loan_status                                           None
# orig_projected_additional_accrued_interest                     None
# hardship_payoff_balance_amount                                 None
# hardship_last_payment_amount                                   None
# debt_settlement_flag                                              N
# debt_settlement_flag_date                                      None
# settlement_status                                              None
# settlement_date                                                None
# settlement_amount                                              None
# settlement_percentage                                          None
# settlement_term                                                None
#
#                                                                 1  \
# id                                                           None
# member_id                                                    None
# loan_amnt                                                    9000
# funded_amnt                                                  9000
# funded_amnt_inv                                              9000
# term                                                    36 months
# int_rate                                                   15.31%
# installment                                                313.36
# grade                                                           C
# sub_grade                                                      C5
# emp_title                                   Senior Case Assistant
# emp_length                                                9 years
# home_ownership                                               RENT
# annual_inc                                                  52000
# verification_status                               Source Verified
# issue_d                                                  Mar-2016
# loan_status                                            Fully Paid
# pymnt_plan                                                      n
# url                                                          None
# desc                                                         None
# purpose                                        debt_consolidation
# title                                          Debt consolidation
# zip_code                                                    945xx
# addr_state                                                     CA
# dti                                                         18.86
# delinq_2yrs                                                     0
# earliest_cr_line                                         Nov-1999
# inq_last_6mths                                                  0
# mths_since_last_delinq                                         24
# mths_since_last_record                                       None
# open_acc                                                        6
# pub_rec                                                         0
# revol_bal                                                   11713
# revol_util                                                  73.7%
# total_acc                                                      13
# initial_list_status                                             w
# out_prncp                                                    0.00
# out_prncp_inv                                                0.00
# total_pymnt                                      10193.6517427984
# total_pymnt_inv                                          10193.65
# total_rec_prncp                                           9000.00
# total_rec_int                                             1193.65
# total_rec_late_fee                                            0.0
# recoveries                                                    0.0
# collection_recovery_fee                                       0.0
# last_pymnt_d                                             Mar-2017
# last_pymnt_amnt                                           7064.14
# next_pymnt_d                                                 None
# last_credit_pull_d                                       Jul-2019
# collections_12_mths_ex_med                                      0
# mths_since_last_major_derog                                  None
# policy_code                                                     1
# application_type                                       Individual
# annual_inc_joint                                             None
# dti_joint                                                    None
# verification_status_joint                                    None
# acc_now_delinq                                                  0
# tot_coll_amt                                                    0
# tot_cur_bal                                                 52953
# open_acc_6m                                                     2
# open_act_il                                                     1
# open_il_12m                                                     1
# open_il_24m                                                     1
# mths_since_rcnt_il                                              4
# total_bal_il                                                41240
# il_util                                                      None
# open_rv_12m                                                     3
# open_rv_24m                                                     3
# max_bal_bc                                                   3789
# all_util                                                       74
# total_rev_hi_lim                                            15900
# inq_fi                                                          0
# total_cu_tl                                                     1
# inq_last_12m                                                    2
# acc_open_past_24mths                                            4
# avg_cur_bal                                                  8826
# bc_open_to_buy                                               4187
# bc_util                                                      73.7
# chargeoff_within_12_mths                                        0
# delinq_amnt                                                     0
# mo_sin_old_il_acct                                            125
# mo_sin_old_rev_tl_op                                          196
# mo_sin_rcnt_rev_tl_op                                           1
# mo_sin_rcnt_tl                                                  1
# mort_acc                                                        0
# mths_since_recent_bc                                            1
# mths_since_recent_bc_dlq                                     None
# mths_since_recent_inq                                           4
# mths_since_recent_revol_delinq                               None
# num_accts_ever_120_pd                                           0
# num_actv_bc_tl                                                  5
# num_actv_rev_tl                                                 5
# num_bc_sats                                                     5
# num_bc_tl                                                       9
# num_il_tl                                                       3
# num_op_rev_tl                                                   5
# num_rev_accts                                                  10
# num_rev_tl_bal_gt_0                                             5
# num_sats                                                        6
# num_tl_120dpd_2m                                                0
# num_tl_30dpd                                                    0
# num_tl_90g_dpd_24m                                              0
# num_tl_op_past_12m                                              4
# pct_tl_nvr_dlq                                               92.3
# percent_bc_gt_75                                               80
# pub_rec_bankruptcies                                            0
# tax_liens                                                       0
# tot_hi_cred_lim                                             58425
# total_bal_ex_mort                                           52953
# total_bc_limit                                              15900
# total_il_high_credit_limit                                  42525
# revol_bal_joint                                              None
# sec_app_earliest_cr_line                                     None
# sec_app_inq_last_6mths                                       None
# sec_app_mort_acc                                             None
# sec_app_open_acc                                             None
# sec_app_revol_util                                           None
# sec_app_open_act_il                                          None
# sec_app_num_rev_accts                                        None
# sec_app_chargeoff_within_12_mths                             None
# sec_app_collections_12_mths_ex_med                           None
# sec_app_mths_since_last_major_derog                          None
# hardship_flag                                                   N
# hardship_type                                                None
# hardship_reason                                              None
# hardship_status                                              None
# deferral_term                                                None
# hardship_amount                                              None
# hardship_start_date                                          None
# hardship_end_date                                            None
# payment_plan_start_date                                      None
# hardship_length                                              None
# hardship_dpd                                                 None
# hardship_loan_status                                         None
# orig_projected_additional_accrued_interest                   None
# hardship_payoff_balance_amount                               None
# hardship_last_payment_amount                                 None
# debt_settlement_flag                                            N
# debt_settlement_flag_date                                    None
# settlement_status                                            None
# settlement_date                                              None
# settlement_amount                                            None
# settlement_percentage                                        None
# settlement_term                                              None
#
#                                                              2  \
# id                                                        None
# member_id                                                 None
# loan_amnt                                                 8000
# funded_amnt                                               8000
# funded_amnt_inv                                           8000
# term                                                 36 months
# int_rate                                                10.75%
# installment                                             260.97
# grade                                                        B
# sub_grade                                                   B4
# emp_title                                                   Vp
# emp_length                                             5 years
# home_ownership                                            RENT
# annual_inc                                               73000
# verification_status                            Source Verified
# issue_d                                               Mar-2016
# loan_status                                         Fully Paid
# pymnt_plan                                                   n
# url                                                       None
# desc                                                      None
# purpose                                     debt_consolidation
# title                                       Debt consolidation
# zip_code                                                 917xx
# addr_state                                                  CA
# dti                                                      10.85
# delinq_2yrs                                                  0
# earliest_cr_line                                      Jan-2005
# inq_last_6mths                                               2
# mths_since_last_delinq                                    None
# mths_since_last_record                                    None
# open_acc                                                     5
# pub_rec                                                      0
# revol_bal                                                 1824
# revol_util                                                  8%
# total_acc                                                    8
# initial_list_status                                          w
# out_prncp                                                 0.00
# out_prncp_inv                                             0.00
# total_pymnt                                     9421.150892764
# total_pymnt_inv                                        9421.15
# total_rec_prncp                                        8000.00
# total_rec_int                                          1421.15
# total_rec_late_fee                                         0.0
# recoveries                                                 0.0
# collection_recovery_fee                                    0.0
# last_pymnt_d                                          Mar-2019
# last_pymnt_amnt                                          521.9
# next_pymnt_d                                              None
# last_credit_pull_d                                    May-2019
# collections_12_mths_ex_med                                   0
# mths_since_last_major_derog                               None
# policy_code                                                  1
# application_type                                    Individual
# annual_inc_joint                                          None
# dti_joint                                                 None
# verification_status_joint                                 None
# acc_now_delinq                                               0
# tot_coll_amt                                                 0
# tot_cur_bal                                              62125
# open_acc_6m                                                  1
# open_act_il                                                  2
# open_il_12m                                                  0
# open_il_24m                                                  1
# mths_since_rcnt_il                                          13
# total_bal_il                                             60301
# il_util                                                     85
# open_rv_12m                                                  2
# open_rv_24m                                                  3
# max_bal_bc                                                 854
# all_util                                                    47
# total_rev_hi_lim                                         22800
# inq_fi                                                       0
# total_cu_tl                                                  1
# inq_last_12m                                                 2
# acc_open_past_24mths                                         4
# avg_cur_bal                                              12425
# bc_open_to_buy                                           20571
# bc_util                                                    6.5
# chargeoff_within_12_mths                                     0
# delinq_amnt                                                  0
# mo_sin_old_il_acct                                         134
# mo_sin_old_rev_tl_op                                        84
# mo_sin_rcnt_rev_tl_op                                        2
# mo_sin_rcnt_tl                                               2
# mort_acc                                                     0
# mths_since_recent_bc                                         2
# mths_since_recent_bc_dlq                                  None
# mths_since_recent_inq                                        0
# mths_since_recent_revol_delinq                            None
# num_accts_ever_120_pd                                        0
# num_actv_bc_tl                                               2
# num_actv_rev_tl                                              3
# num_bc_sats                                                  2
# num_bc_tl                                                    3
# num_il_tl                                                    4
# num_op_rev_tl                                                3
# num_rev_accts                                                4
# num_rev_tl_bal_gt_0                                          3
# num_sats                                                     5
# num_tl_120dpd_2m                                             0
# num_tl_30dpd                                                 0
# num_tl_90g_dpd_24m                                           0
# num_tl_op_past_12m                                           2
# pct_tl_nvr_dlq                                             100
# percent_bc_gt_75                                            50
# pub_rec_bankruptcies                                         0
# tax_liens                                                    0
# tot_hi_cred_lim                                          78840
# total_bal_ex_mort                                        62125
# total_bc_limit                                           22000
# total_il_high_credit_limit                               56040
# revol_bal_joint                                           None
# sec_app_earliest_cr_line                                  None
# sec_app_inq_last_6mths                                    None
# sec_app_mort_acc                                          None
# sec_app_open_acc                                          None
# sec_app_revol_util                                        None
# sec_app_open_act_il                                       None
# sec_app_num_rev_accts                                     None
# sec_app_chargeoff_within_12_mths                          None
# sec_app_collections_12_mths_ex_med                        None
# sec_app_mths_since_last_major_derog                       None
# hardship_flag                                                N
# hardship_type                                             None
# hardship_reason                                           None
# hardship_status                                           None
# deferral_term                                             None
# hardship_amount                                           None
# hardship_start_date                                       None
# hardship_end_date                                         None
# payment_plan_start_date                                   None
# hardship_length                                           None
# hardship_dpd                                              None
# hardship_loan_status                                      None
# orig_projected_additional_accrued_interest                None
# hardship_payoff_balance_amount                            None
# hardship_last_payment_amount                              None
# debt_settlement_flag                                         N
# debt_settlement_flag_date                                 None
# settlement_status                                         None
# settlement_date                                           None
# settlement_amount                                         None
# settlement_percentage                                     None
# settlement_term                                           None
#
#                                                              3  \
# id                                                        None
# member_id                                                 None
# loan_amnt                                                25000
# funded_amnt                                              25000
# funded_amnt_inv                                          25000
# term                                                 60 months
# int_rate                                                12.99%
# installment                                              568.7
# grade                                                        C
# sub_grade                                                   C2
# emp_title                                       Administration
# emp_length                                           10+ years
# home_ownership                                            RENT
# annual_inc                                              138000
# verification_status                               Not Verified
# issue_d                                               Mar-2016
# loan_status                                        Charged Off
# pymnt_plan                                                   n
# url                                                       None
# desc                                                      None
# purpose                                     debt_consolidation
# title                                       Debt consolidation
# zip_code                                                 078xx
# addr_state                                                  NJ
# dti                                                      12.44
# delinq_2yrs                                                  0
# earliest_cr_line                                      Aug-1995
# inq_last_6mths                                               1
# mths_since_last_delinq                                    None
# mths_since_last_record                                      64
# open_acc                                                     9
# pub_rec                                                      1
# revol_bal                                                 8577
# revol_util                                               37.1%
# total_acc                                                   24
# initial_list_status                                          w
# out_prncp                                                 0.00
# out_prncp_inv                                             0.00
# total_pymnt                                           17420.54
# total_pymnt_inv                                       17420.54
# total_rec_prncp                                       10091.32
# total_rec_int                                          6364.90
# total_rec_late_fee                                         0.0
# recoveries                                              964.32
# collection_recovery_fee                               173.5776
# last_pymnt_d                                          Sep-2018
# last_pymnt_amnt                                          568.7
# next_pymnt_d                                              None
# last_credit_pull_d                                    May-2019
# collections_12_mths_ex_med                                   0
# mths_since_last_major_derog                               None
# policy_code                                                  1
# application_type                                    Individual
# annual_inc_joint                                          None
# dti_joint                                                 None
# verification_status_joint                                 None
# acc_now_delinq                                               0
# tot_coll_amt                                                 0
# tot_cur_bal                                              11565
# open_acc_6m                                                  2
# open_act_il                                                  1
# open_il_12m                                                  0
# open_il_24m                                                  0
# mths_since_rcnt_il                                          33
# total_bal_il                                              2988
# il_util                                                   None
# open_rv_12m                                                  2
# open_rv_24m                                                  6
# max_bal_bc                                                4350
# all_util                                                    37
# total_rev_hi_lim                                         23100
# inq_fi                                                       1
# total_cu_tl                                                  0
# inq_last_12m                                                 2
# acc_open_past_24mths                                         6
# avg_cur_bal                                               1285
# bc_open_to_buy                                            9281
# bc_util                                                   45.4
# chargeoff_within_12_mths                                     0
# delinq_amnt                                                  0
# mo_sin_old_il_acct                                         136
# mo_sin_old_rev_tl_op                                       247
# mo_sin_rcnt_rev_tl_op                                        2
# mo_sin_rcnt_tl                                               2
# mort_acc                                                     0
# mths_since_recent_bc                                         2
# mths_since_recent_bc_dlq                                  None
# mths_since_recent_inq                                        0
# mths_since_recent_revol_delinq                            None
# num_accts_ever_120_pd                                        0
# num_actv_bc_tl                                               5
# num_actv_rev_tl                                              8
# num_bc_sats                                                  5
# num_bc_tl                                                   11
# num_il_tl                                                    3
# num_op_rev_tl                                                8
# num_rev_accts                                               20
# num_rev_tl_bal_gt_0                                          8
# num_sats                                                     9
# num_tl_120dpd_2m                                             0
# num_tl_30dpd                                                 0
# num_tl_90g_dpd_24m                                           0
# num_tl_op_past_12m                                           2
# pct_tl_nvr_dlq                                             100
# percent_bc_gt_75                                            20
# pub_rec_bankruptcies                                         1
# tax_liens                                                    0
# tot_hi_cred_lim                                          58967
# total_bal_ex_mort                                        11565
# total_bc_limit                                           17000
# total_il_high_credit_limit                               35867
# revol_bal_joint                                           None
# sec_app_earliest_cr_line                                  None
# sec_app_inq_last_6mths                                    None
# sec_app_mort_acc                                          None
# sec_app_open_acc                                          None
# sec_app_revol_util                                        None
# sec_app_open_act_il                                       None
# sec_app_num_rev_accts                                     None
# sec_app_chargeoff_within_12_mths                          None
# sec_app_collections_12_mths_ex_med                        None
# sec_app_mths_since_last_major_derog                       None
# hardship_flag                                                N
# hardship_type                                             None
# hardship_reason                                           None
# hardship_status                                           None
# deferral_term                                             None
# hardship_amount                                           None
# hardship_start_date                                       None
# hardship_end_date                                         None
# payment_plan_start_date                                   None
# hardship_length                                           None
# hardship_dpd                                              None
# hardship_loan_status                                      None
# orig_projected_additional_accrued_interest                None
# hardship_payoff_balance_amount                            None
# hardship_last_payment_amount                              None
# debt_settlement_flag                                         N
# debt_settlement_flag_date                                 None
# settlement_status                                         None
# settlement_date                                           None
# settlement_amount                                         None
# settlement_percentage                                     None
# settlement_term                                           None
#
#                                                              4  \
# id                                                        None
# member_id                                                 None
# loan_amnt                                                35000
# funded_amnt                                              35000
# funded_amnt_inv                                          35000
# term                                                 60 months
# int_rate                                                18.25%
# installment                                             893.54
# grade                                                        D
# sub_grade                                                   D3
# emp_title                                         Electrician
# emp_length                                           10+ years
# home_ownership                                        MORTGAGE
# annual_inc                                              134000
# verification_status                                   Verified
# issue_d                                               Mar-2016
# loan_status                                         Fully Paid
# pymnt_plan                                                   n
# url                                                       None
# desc                                                      None
# purpose                                     debt_consolidation
# title                                       Debt consolidation
# zip_code                                                 605xx
# addr_state                                                  IL
# dti                                                      25.69
# delinq_2yrs                                                  0
# earliest_cr_line                                      Nov-1996
# inq_last_6mths                                               0
# mths_since_last_delinq                                    None
# mths_since_last_record                                    None
# open_acc                                                    23
# pub_rec                                                      0
# revol_bal                                                41602
# revol_util                                                 63%
# total_acc                                                   26
# initial_list_status                                          w
# out_prncp                                                 0.00
# out_prncp_inv                                             0.00
# total_pymnt                                   46733.2645332959
# total_pymnt_inv                                       46733.26
# total_rec_prncp                                       35000.00
# total_rec_int                                         11733.26
# total_rec_late_fee                                         0.0
# recoveries                                                 0.0
# collection_recovery_fee                                    0.0
# last_pymnt_d                                          Jun-2018
# last_pymnt_amnt                                         354.46
# next_pymnt_d                                              None
# last_credit_pull_d                                    Aug-2019
# collections_12_mths_ex_med                                   0
# mths_since_last_major_derog                                 48
# policy_code                                                  1
# application_type                                    Individual
# annual_inc_joint                                          None
# dti_joint                                                 None
# verification_status_joint                                 None
# acc_now_delinq                                               0
# tot_coll_amt                                                 0
# tot_cur_bal                                             310728
# open_acc_6m                                                  1
# open_act_il                                                  4
# open_il_12m                                                  3
# open_il_24m                                                  4
# mths_since_rcnt_il                                           7
# total_bal_il                                             44024
# il_util                                                     82
# open_rv_12m                                                  3
# open_rv_24m                                                  9
# max_bal_bc                                                6819
# all_util                                                    63
# total_rev_hi_lim                                         66400
# inq_fi                                                       0
# total_cu_tl                                                  0
# inq_last_12m                                                 1
# acc_open_past_24mths                                        13
# avg_cur_bal                                              16354
# bc_open_to_buy                                            6438
# bc_util                                                     72
# chargeoff_within_12_mths                                     0
# delinq_amnt                                                  0
# mo_sin_old_il_acct                                          19
# mo_sin_old_rev_tl_op                                       232
# mo_sin_rcnt_rev_tl_op                                        5
# mo_sin_rcnt_tl                                               5
# mort_acc                                                     2
# mths_since_recent_bc                                         5
# mths_since_recent_bc_dlq                                  None
# mths_since_recent_inq                                        7
# mths_since_recent_revol_delinq                            None
# num_accts_ever_120_pd                                        0
# num_actv_bc_tl                                               8
# num_actv_rev_tl                                             13
# num_bc_sats                                                  9
# num_bc_tl                                                    9
# num_il_tl                                                    4
# num_op_rev_tl                                               13
# num_rev_accts                                               20
# num_rev_tl_bal_gt_0                                         10
# num_sats                                                    19
# num_tl_120dpd_2m                                          None
# num_tl_30dpd                                                 0
# num_tl_90g_dpd_24m                                           0
# num_tl_op_past_12m                                           6
# pct_tl_nvr_dlq                                             100
# percent_bc_gt_75                                            50
# pub_rec_bankruptcies                                         0
# tax_liens                                                    0
# tot_hi_cred_lim                                         355711
# total_bal_ex_mort                                        85626
# total_bc_limit                                           51500
# total_il_high_credit_limit                               53811
# revol_bal_joint                                           None
# sec_app_earliest_cr_line                                  None
# sec_app_inq_last_6mths                                    None
# sec_app_mort_acc                                          None
# sec_app_open_acc                                          None
# sec_app_revol_util                                        None
# sec_app_open_act_il                                       None
# sec_app_num_rev_accts                                     None
# sec_app_chargeoff_within_12_mths                          None
# sec_app_collections_12_mths_ex_med                        None
# sec_app_mths_since_last_major_derog                       None
# hardship_flag                                                N
# hardship_type                                             None
# hardship_reason                                           None
# hardship_status                                           None
# deferral_term                                             None
# hardship_amount                                           None
# ...
# last_pymnt_amnt                                        406.32
# next_pymnt_d                                             None
# last_credit_pull_d                                   Dec-2018
# collections_12_mths_ex_med                                  0
# mths_since_last_major_derog                              None
# policy_code                                                 1
# application_type                                   Individual
# annual_inc_joint                                         None
# dti_joint                                                None
# verification_status_joint                                None
# acc_now_delinq                                              0
# tot_coll_amt                                             2124
# tot_cur_bal                                            156318
# open_acc_6m                                                 3
# open_act_il                                                 1
# open_il_12m                                                 1
# open_il_24m                                                 3
# mths_since_rcnt_il                                          3
# total_bal_il                                             7560
# il_util                                                    98
# open_rv_12m                                                 3
# open_rv_24m                                                 5
# max_bal_bc                                                361
# all_util                                                   65
# total_rev_hi_lim                                         6600
# inq_fi                                                      0
# total_cu_tl                                                 1
# inq_last_12m                                                0
# acc_open_past_24mths                                        8
# avg_cur_bal                                             22331
# bc_open_to_buy                                           1809
# bc_util                                                  30.4
# chargeoff_within_12_mths                                    0
# delinq_amnt                                                 0
# mo_sin_old_il_acct                                        121
# mo_sin_old_rev_tl_op                                      132
# mo_sin_rcnt_rev_tl_op                                       2
# mo_sin_rcnt_tl                                              2
# mort_acc                                                    1
# mths_since_recent_bc                                        2
# mths_since_recent_bc_dlq                                   81
# mths_since_recent_inq                                      14
# mths_since_recent_revol_delinq                             81
# num_accts_ever_120_pd                                       0
# num_actv_bc_tl                                              3
# num_actv_rev_tl                                             4
# num_bc_sats                                                 3
# num_bc_tl                                                   4
# num_il_tl                                                   7
# num_op_rev_tl                                               5
# num_rev_accts                                               6
# num_rev_tl_bal_gt_0                                         4
# num_sats                                                    7
# num_tl_120dpd_2m                                            0
# num_tl_30dpd                                                0
# num_tl_90g_dpd_24m                                          0
# num_tl_op_past_12m                                          4
# pct_tl_nvr_dlq                                           84.6
# percent_bc_gt_75                                            0
# pub_rec_bankruptcies                                        0
# tax_liens                                                   0
# tot_hi_cred_lim                                        200449
# total_bal_ex_mort                                        9333
# total_bc_limit                                           2600
# total_il_high_credit_limit                               7704
# revol_bal_joint                                          None
# sec_app_earliest_cr_line                                 None
# sec_app_inq_last_6mths                                   None
# sec_app_mort_acc                                         None
# sec_app_open_acc                                         None
# sec_app_revol_util                                       None
# sec_app_open_act_il                                      None
# sec_app_num_rev_accts                                    None
# sec_app_chargeoff_within_12_mths                         None
# sec_app_collections_12_mths_ex_med                       None
# sec_app_mths_since_last_major_derog                      None
# hardship_flag                                               N
# hardship_type                                            None
# hardship_reason                                          None
# hardship_status                                          None
# deferral_term                                            None
# hardship_amount                                          None
# hardship_start_date                                      None
# hardship_end_date                                        None
# payment_plan_start_date                                  None
# hardship_length                                          None
# hardship_dpd                                             None
# hardship_loan_status                                     None
# orig_projected_additional_accrued_interest               None
# hardship_payoff_balance_amount                           None
# hardship_last_payment_amount                             None
# debt_settlement_flag                                        N
# debt_settlement_flag_date                                None
# settlement_status                                        None
# settlement_date                                          None
# settlement_amount                                        None
# settlement_percentage                                    None
# settlement_term                                          None
#
#                                                               9
# id                                                         None
# member_id                                                  None
# loan_amnt                                                 16000
# funded_amnt                                               16000
# funded_amnt_inv                                           16000
# term                                                  60 months
# int_rate                                                  9.75%
# installment                                              337.99
# grade                                                         B
# sub_grade                                                    B3
# emp_title                                   CHEMICAL SPECIALIST
# emp_length                                            10+ years
# home_ownership                                              OWN
# annual_inc                                               120000
# verification_status                             Source Verified
# issue_d                                                Mar-2016
# loan_status                                             Current
# pymnt_plan                                                    n
# url                                                        None
# desc                                                       None
# purpose                                      debt_consolidation
# title                                        Debt consolidation
# zip_code                                                  060xx
# addr_state                                                   CT
# dti                                                       13.68
# delinq_2yrs                                                   1
# earliest_cr_line                                       Nov-1994
# inq_last_6mths                                                0
# mths_since_last_delinq                                       20
# mths_since_last_record                                     None
# open_acc                                                     25
# pub_rec                                                       0
# revol_bal                                                 16763
# revol_util                                                30.5%
# total_acc                                                    38
# initial_list_status                                           w
# out_prncp                                               6215.78
# out_prncp_inv                                           6215.78
# total_pymnt                                            13502.27
# total_pymnt_inv                                        13502.27
# total_rec_prncp                                         9784.22
# total_rec_int                                           3718.05
# total_rec_late_fee                                          0.0
# recoveries                                                  0.0
# collection_recovery_fee                                     0.0
# last_pymnt_d                                           Jul-2019
# last_pymnt_amnt                                          337.99
# next_pymnt_d                                           Sep-2019
# last_credit_pull_d                                     Aug-2019
# collections_12_mths_ex_med                                    1
# mths_since_last_major_derog                                  53
# policy_code                                                   1
# application_type                                     Individual
# annual_inc_joint                                           None
# dti_joint                                                  None
# verification_status_joint                                  None
# acc_now_delinq                                                0
# tot_coll_amt                                                350
# tot_cur_bal                                              109019
# open_acc_6m                                                   2
# open_act_il                                                   3
# open_il_12m                                                   2
# open_il_24m                                                   2
# mths_since_rcnt_il                                            2
# total_bal_il                                              25781
# il_util                                                      68
# open_rv_12m                                                   1
# open_rv_24m                                                   7
# max_bal_bc                                                 4244
# all_util                                                     46
# total_rev_hi_lim                                          54900
# inq_fi                                                        5
# total_cu_tl                                                   1
# inq_last_12m                                                 11
# acc_open_past_24mths                                         11
# avg_cur_bal                                                4542
# bc_open_to_buy                                            12857
# bc_util                                                    48.6
# chargeoff_within_12_mths                                      0
# delinq_amnt                                                   0
# mo_sin_old_il_acct                                          157
# mo_sin_old_rev_tl_op                                        256
# mo_sin_rcnt_rev_tl_op                                        12
# mo_sin_rcnt_tl                                                2
# mort_acc                                                      1
# mths_since_recent_bc                                         14
# mths_since_recent_bc_dlq                                   None
# mths_since_recent_inq                                         2
# mths_since_recent_revol_delinq                               20
# num_accts_ever_120_pd                                         1
# num_actv_bc_tl                                                5
# num_actv_rev_tl                                              13
# num_bc_sats                                                   6
# num_bc_tl                                                    10
# num_il_tl                                                     8
# num_op_rev_tl                                                19
# num_rev_accts                                                28
# num_rev_tl_bal_gt_0                                          13
# num_sats                                                     25
# num_tl_120dpd_2m                                              0
# num_tl_30dpd                                                  0
# num_tl_90g_dpd_24m                                            0
# num_tl_op_past_12m                                            5
# pct_tl_nvr_dlq                                             94.6
# percent_bc_gt_75                                           16.7
# pub_rec_bankruptcies                                          0
# tax_liens                                                     0
# tot_hi_cred_lim                                          160515
# total_bal_ex_mort                                         42544
# total_bc_limit                                            25000
# total_il_high_credit_limit                                38196
# revol_bal_joint                                            None
# sec_app_earliest_cr_line                                   None
# sec_app_inq_last_6mths                                     None
# sec_app_mort_acc                                           None
# sec_app_open_acc                                           None
# sec_app_revol_util                                         None
# sec_app_open_act_il                                        None
# sec_app_num_rev_accts                                      None
# sec_app_chargeoff_within_12_mths                           None
# sec_app_collections_12_mths_ex_med                         None
# sec_app_mths_since_last_major_derog                        None
# hardship_flag                                                 N
# hardship_type                                              None
# hardship_reason                                            None
# hardship_status                                            None
# deferral_term                                              None
# hardship_amount                                            None
# hardship_start_date                                        None
# hardship_end_date                                          None
# payment_plan_start_date                                    None
# hardship_length                                            None
# hardship_dpd                                               None
# hardship_loan_status                                       None
# orig_projected_additional_accrued_interest                 None
# hardship_payoff_balance_amount                             None
# hardship_last_payment_amount                               None
# debt_settlement_flag                                          N
# debt_settlement_flag_date                                  None
# settlement_status                                          None
# settlement_date                                            None
# settlement_amount                                          None
# settlement_percentage                                      None
# settlement_term                                            None

# %%
from pyspark.sql import functions as sparkf

# %%
from pyspark.sql.types import *

# %%
clean_symbol = sparkf.udf(lambda x: x.replace('%',''))

# %%
clean_text = sparkf.udf(lambda x:x.replace('years','').replace('+',''))

# %%
crunched_raw_df = raw_df.withColumn('loan_amnt',sparkf.col('loan_amnt').cast(FloatType()))\
.withColumn('int_rate',clean_symbol('int_rate'))\
.withColumn('int_rate',sparkf.col('int_rate').cast(FloatType()))\
.withColumn('emp_length',clean_text('emp_length'))\
.withColumn('emp_length',sparkf.col('emp_length').cast(FloatType()))

# %% [markdown]
# ##### วาง data ใน Trusted Zone เพื่อ Support -> (1) Descriptive Analytics with Interactive Query (2) ELT ลดบวมของ DW

# %%
! hdfs dfs -rm -r "/user/root/crunched_data/"
# Out:
# Deleted /user/root/crunched_data

# %%
crunched_raw_df.count()
# Out:
# 1432439

# %%
crunched_raw_df.write.mode('overwrite').parquet('/user/root/crunched_data/')

# %% [markdown]
# ### 4. Data Analytics with Various SQL Queries.

# %% [markdown]
# #### สร้าง table ชื่อ analytics_loan เพื่อ Summarized ทางด้านการเงิน

# %%
! hive -e "DROP TABLE IF EXISTS analytics_loan"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# Time taken: 2.131 seconds

# %%
! hive -e "CREATE EXTERNAL TABLE IF NOT EXISTS analytics_loan (grade string, loan_amnt float, int_rate float) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' STORED AS PARQUET LOCATION '/user/root/crunched_data/' tblproperties ('skip.header.line.count'='1')"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# Time taken: 2.135 seconds

# %%
! hive -e "select count(*) from analytics_loan"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# Query ID = root_20200823023838_04214700-a180-4958-a58c-c06ab920ef0b
# Total jobs = 1
# Launching Job 1 out of 1
# Status: Running (Executing on YARN cluster with App id application_1598147476368_0054)
#
# OK
# 1432439
# Time taken: 31.682 seconds, Fetched: 1 row(s)

# %%
! hive -e "show columns from analytics_loan"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# grade
# loan_amnt
# int_rate
# Time taken: 1.812 seconds, Fetched: 3 row(s)

# %%
! hive -e "select grade, count(*) as num from analytics_loan group by grade order by num DESC"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# Query ID = root_20200823023932_817f9fbe-bec5-42cb-be86-165ed640da6f
# Total jobs = 1
# Launching Job 1 out of 1
# Status: Running (Executing on YARN cluster with App id application_1598147476368_0057)
#
# OK
# B	424110
# C	421101
# A	302988
# D	191136
# E	68353
# F	19480
# G	5271
# Time taken: 26.112 seconds, Fetched: 7 row(s)

# %%
! hive -e "select grade, int_rate, avg(loan_amnt) from analytics_loan \
group by grade, int_rate order by int_rate ASC"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# Query ID = root_20200823024008_69a35a17-399e-45b4-8845-1ed2d5377fcb
# Total jobs = 1
# Launching Job 1 out of 1
# Status: Running (Executing on YARN cluster with App id application_1598147476368_0059)
#
# OK
# A	5.31	17268.11796122141
# A	5.32	14450.231374989851
# G	6.0	18410.0
# A	6.0	16021.42857142857
# B	6.0	15058.870967741936
# C	6.0	15207.24043715847
# D	6.0	14717.857142857143
# E	6.0	25147.727272727272
# F	6.0	24450.96153846154
# A	6.07	15201.17055190277
# A	6.08	15591.83793800539
# A	6.11	18153.841525670945
# A	6.19	15080.01512859304
# A	6.24	12722.222222222223
# A	6.46	17008.949089623475
# A	6.49	14254.788809226933
# A	6.67	15889.998285910182
# A	6.71	14697.217153284671
# A	6.72	15054.450261780104
# A	6.83	14764.413722478239
# A	6.89	15700.0
# A	6.97	14107.375696306994
# A	6.99	13424.824452027826
# A	7.02	15187.031381003713
# A	7.21	15023.153006611397
# A	7.24	13945.10055816426
# A	7.26	12930.76923076923
# A	7.34	15537.665911298154
# A	7.35	16061.002973776696
# A	7.39	15260.836187214612
# A	7.46	15931.09489889706
# A	7.49	14523.404408586659
# A	7.56	14598.410438908659
# A	7.59	12257.979407979408
# A	7.84	16536.627024291498
# A	7.89	15904.400121802679
# A	7.91	16401.22905027933
# A	7.96	13959.618076384722
# A	7.97	14548.229329173168
# A	7.99	13790.363733686787
# A	8.08	14143.612732832917
# A	8.19	17415.215200379418
# B	8.24	12900.062209416541
# B	8.38	15288.0
# B	8.39	14352.56277235941
# A	8.46	14822.503332063976
# B	8.49	14698.781407035176
# A	8.59	12443.589907786885
# A	8.81	14980.320203413205
# B	8.99	12428.108900973097
# B	9.16	13509.142939592151
# B	9.17	13866.815826660386
# B	9.43	15845.103813871301
# B	9.44	15835.52534448819
# B	9.49	12984.628688408866
# B	9.58	15796.73305805198
# B	9.75	14858.143585386577
# B	9.76	15998.4375
# B	9.8	15303.619604316547
# B	9.92	17076.432490094485
# B	9.93	17430.00123031496
# B	10.07	16627.968641918378
# B	10.08	16451.292381749685
# B	10.33	17115.666941978114
# B	10.41	13955.074626865671
# B	10.42	16888.152228976698
# B	10.47	16705.6192551881
# B	10.49	13281.665538825917
# B	10.56	14035.281582952815
# B	10.64	14417.741935483871
# B	10.72	16856.820983849095
# B	10.75	14231.57365402722
# B	10.78	14618.714222809334
# B	10.9	16659.527687296417
# B	10.91	14135.627899271041
# B	10.99	13110.425832809553
# B	11.02	16835.426748790145
# B	11.05	16160.549438915943
# B	11.06	14802.817329925763
# B	11.16	15000.0
# B	11.22	13767.592592592593
# B	11.31	14820.420456358705
# B	11.39	13022.364509736342
# B	11.44	13314.391569989453
# B	11.47	13624.081131436315
# B	11.48	14068.846899224805
# B	11.49	12777.446871430902
# B	11.55	16739.644412799465
# B	11.71	15404.489904357068
# B	11.8	18012.034357202876
# B	11.98	16252.44130779202
# B	11.99	16426.38014527845
# C	11.99	14520.601581299416
# B	12.13	16207.682232346242
# B	12.4	18011.402243589742
# C	12.59	16507.25806451613
# C	12.61	16755.65309520206
# C	12.62	17046.77183173589
# B	12.73	16511.43619805297
# C	12.74	14662.92433951926
# C	12.79	12872.676063453571
# C	12.88	15793.268171806167
# B	12.98	17057.891271632805
# C	12.99	14956.452589418777
# C	13.06	16544.64078121367
# B	13.08	17746.67874396135
# C	13.18	17492.647058823528
# C	13.19	12975.0
# C	13.44	16543.385471898197
# C	13.49	14237.797816437936
# C	13.56	16334.92818876097
# C	13.58	16403.340893230983
# C	13.59	16347.527865104315
# C	13.67	15497.25975975976
# C	13.9	16754.932546374366
# C	13.99	15058.497514859602
# C	14.03	16096.51148120111
# C	14.07	16658.710544571626
# C	14.08	16333.122119815669
# C	14.46	15426.979015167255
# C	14.47	16373.934404893604
# C	14.48	17201.041666666668
# C	14.49	15102.371830985916
# C	14.52	16025.779453105035
# C	14.74	16823.78663003663
# D	14.77	10000.0
# C	14.85	17067.85465924896
# C	14.99	16001.480205442307
# C	15.02	16188.163676860102
# C	15.04	16183.506693198264
# C	15.05	16287.854221443178
# D	15.29	5050.0
# C	15.31	15281.708891895216
# D	15.41	16235.714285714286
# C	15.49	15826.548614741245
# C	15.57	16586.323392357874
# C	15.59	15444.605459985041
# D	15.59	8900.0
# D	15.77	17303.5
# C	15.99	16414.083121092845
# C	16.01	16299.620411301172
# C	16.02	16242.813831530646
# C	16.14	15926.215567612688
# D	16.29	15192.37978184053
# C	16.4	15853.854790419162
# C	16.46	15825.325502405887
# D	16.55	15796.153846153846
# D	16.59	17702.513661202185
# C	16.91	15798.251461571368
# D	16.99	15894.69318091609
# D	17.09	16562.475775193798
# C	17.19	15907.544141252007
# D	17.27	16111.248884924174
# D	17.47	16091.604603926879
# D	17.57	13098.333333333334
# D	17.86	14950.0
# D	17.97	16077.695791364098
# D	17.99	15769.560520563266
# D	18.06	15891.17349519474
# E	18.2	16350.0
# D	18.25	15615.547546788062
# D	18.45	15942.783643521832
# D	18.49	19175.956521739132
# E	18.49	19081.25
# D	18.94	15830.08097165992
# D	18.99	16454.027784145615
# E	18.99	17451.478679504813
# D	19.03	16067.384020618556
# D	19.42	15962.63983220136
# E	19.48	18478.60501567398
# D	19.53	16852.77120315582
# E	19.89	18598.77049180328
# D	19.92	15790.8840853523
# D	19.99	15636.62657032597
# E	19.99	16910.475708502025
# D	20.0	16148.016220955722
# D	20.39	15862.334947183099
# E	20.5	19876.901565995526
# E	20.75	17938.570409134158
# D	20.89	15735.694608421882
# E	20.99	15985.28591352859
# E	21.18	17752.729199788024
# D	21.45	16574.346301020407
# E	21.48	20155.68820224719
# D	21.49	17261.627814779575
# D	21.85	16009.826824732683
# E	21.97	19098.038903061224
# F	21.99	16525.0
# D	22.35	17073.772282418733
# E	22.35	17600.672043010753
# E	22.39	17181.615897191812
# E	22.45	19328.571428571428
# F	22.45	19502.618243243243
# D	22.5	16017.289959016394
# E	22.74	17587.571479628306
# E	22.9	12519.726775956284
# E	22.91	12641.091954022988
# F	22.99	15333.333333333334
# F	23.13	18985.83273251622
# E	23.32	17610.49160671463
# E	23.4	11875.881330685204
# E	23.87	12952.466907340553
# E	23.88	16661.38316151203
# E	23.99	16780.8071449748
# F	23.99	4675.0
# F	24.11	18876.061173533082
# F	24.24	19613.602941176472
# E	24.37	12340.725436179982
# E	24.49	18194.627659574468
# E	24.74	15994.48948948949
# E	24.84	17163.793731778427
# E	24.85	18464.019607843136
# E	24.99	18748.192771084337
# F	24.99	19144.19230769231
# D	25.0	13825.352112676057
# F	25.09	20555.33088235294
# F	25.11	17071.136363636364
# E	25.29	19306.647116324537
# E	25.34	15793.705931148901
# F	25.44	19285.677083333332
# E	25.49	18119.36470588235
# F	25.65	20790.771812080537
# F	25.69	19634.00926998841
# E	25.81	17377.720099667775
# E	25.82	18548.291571753987
# F	25.88	18305.847953216373
# F	25.99	10950.0
# F	26.06	21152.75229357798
# F	26.14	18937.5
# E	26.24	18604.478686635946
# E	26.3	18267.802197802197
# E	26.31	15612.524319066148
# F	26.49	19852.014925373136
# F	26.57	17859.3487394958
# E	26.77	18466.75824175824
# G	26.77	12537.5
# F	26.99	19606.62705667276
# G	26.99	20777.272727272728
# E	27.27	17074.89569961489
# G	27.31	17416.666666666668
# F	27.34	19815.957446808512
# G	27.34	18287.63250883392
# G	27.49	16354.166666666666
# F	27.49	20006.39534883721
# F	27.79	20786.944444444445
# G	27.99	20324.358974358973
# G	28.14	18715.401785714286
# G	28.18	20483.118971061092
# G	28.34	18869.871794871793
# G	28.49	18169.23076923077
# G	28.67	17948.571428571428
# F	28.69	18320.564134888118
# F	28.72	19566.491112574062
# D	28.8	16683.04
# G	28.88	20340.89068825911
# E	28.9	13112.5
# E	28.92	16970.454545454544
# E	28.95	14536.206896551725
# E	28.97	17454.6875
# G	28.99	17809.302325581397
# E	29.0	19172.252747252747
# F	29.35	11733.333333333334
# F	29.49	18800.922978994273
# G	29.67	20207.022471910113
# F	29.69	17761.578044596914
# G	29.96	22410.234899328858
# F	29.99	18975.81811263318
# F	30.17	18987.61415525114
# F	30.49	19011.2012987013
# F	30.65	17462.893081761005
# F	30.74	19712.221633085897
# F	30.75	19491.46884272997
# G	30.79	20658.01308258381
# G	30.84	18589.349112426036
# G	30.89	20757.438016528926
# G	30.94	20686.265432098764
# G	30.99	20289.38577586207
# Time taken: 29.29 seconds, Fetched: 277 row(s)

# %% [markdown]
# #### สร้าง table ชื่อ analytics_borrower เพื่อ Summarized ทางด้าน Profile ผู้กู้

# %%
! hive -e "DROP TABLE IF EXISTS analytics_borrower"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# Time taken: 2.066 seconds

# %%
! hive -e "CREATE EXTERNAL TABLE IF NOT EXISTS analytics_borrower (id string, loan_amnt float, int_rate float, emp_length float) ROW FORMAT DELIMITED FIELDS TERMINATED BY ',' STORED AS PARQUET LOCATION '/user/root/crunched_data/' tblproperties ('skip.header.line.count'='1')"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# Time taken: 1.944 seconds

# %%
! hive -e "select emp_length, avg(loan_amnt) from analytics_borrower group by emp_length order by emp_length ASC"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# Query ID = root_20200823024112_2b07df6b-8bd8-4f02-a475-ae31e0216a4e
# Total jobs = 1
# Launching Job 1 out of 1
# Status: Running (Executing on YARN cluster with App id application_1598147476368_0063)
#
# OK
# NULL	14035.318427827466
# 2.0	14808.726487523993
# 3.0	14914.434898375028
# 4.0	14950.930941486971
# 5.0	15249.950950544619
# 6.0	15404.563049099757
# 7.0	15698.691922802001
# 8.0	15829.652785912303
# 9.0	15702.363503114693
# 10.0	16514.665777413527
# Time taken: 30.082 seconds, Fetched: 10 row(s)

# %%
! hive -e "show tables"
# Out:
# Logging initialized using configuration in file:/etc/hive/conf.dist/hive-log4j2.properties Async: true
# OK
# analytics_borrower
# analytics_loan
# Time taken: 1.763 seconds, Fetched: 2 row(s)

# %%
len(raw_df.columns)
# Out:
# 144
